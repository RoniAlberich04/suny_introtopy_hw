# %%
import math

# %%
#Strings

# %%
#slicing (taking something a part out of something)

# %%
name = 'My name is Ryan Mitchell'

# %%
name[0]
# Out:
# 'M'

# %%
name[1]
# Out:
# 'y'

# %%
name[0:7]
# Out:
# 'My name'

# %%
#name[0] -- taking 1 character out of the words, name[0:7] -- taking words out of the sentence

# %%
#Formating

# %%
'My number is: '+str(5)
# Out:
# 'My number is: 5'

# %%
#f'.....' - formatinmg inside string

# %%
f'My number is: {5}'
# Out:
# 'My number is: 5'

# %%
f'My number is {5} and twice is that {2*5}'
# Out:
# 'My number is 5 and twice is that 10'

# %%
#using module math, we can include Pi

# %%
f'Pi equals {math.pi:.2}'
# Out:
# 'Pi equals 3.1'

# %%
#rounding to 1 number after the dot

# %%
#Multi-line string

# %%
myString = '''.....
something about friends and friendship, lmao
hahaha....
.....'''

# %%
myString
# Out:
# '.....\nsomething about friends and friendship, lmao\nhahaha....\n.....'

# %%
#it uses /n to show new paragraphs. and we basically 'call' our string

# %%
print(myString)
# Out:
# .....
# something about friends and friendship, lmao
# hahaha....
# .....

# %%
#we asked to print whaty inside that variable
