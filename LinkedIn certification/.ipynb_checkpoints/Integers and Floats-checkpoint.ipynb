# %%
20 / 4
# Out:
# 5.0

# %%
# оставляет возможность деления с остатком

# %%
4 + 4.0
# Out:
# 8.0

# %%
4 * 4.0
# Out:
# 16.0

# %%
4 ** 4.0
# Out:
# 256.0

# %%
# это все создается в float

# %%
int(4 ** 4.0)
# Out:
# 256

# %%
# Создается целое число

# %%
4 ** 5.6
# Out:
# 2352.5342310339265

# %%
round(4 ** 5.6)
# Out:
# 2353

# %%
# округление до целого числа (строка 14), пример (строка 13)
