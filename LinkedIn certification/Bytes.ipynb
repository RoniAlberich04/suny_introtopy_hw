# %%
#Bytes

# %%
bytes(4)
# Out:
# b'\x00\x00\x00\x00'

# %%
#creates empty file that weights 4 bytes

# %%
smileyBytes = bytes('😁', 'utf-8')
smileyBytes
# Out:
# b'\xf0\x9f\x98\x81'

# %%
smileyBytes.decode('utf-8')
# Out:
# '😁'

# %%
int('101', 2)
# Out:
# 5
